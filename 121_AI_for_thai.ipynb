# %% [markdown]
# <a href="https://colab.research.google.com/github/tiravata/2014-slides/blob/master/121_AI_for_thai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div><img height="45px" src="https://avatars3.githubusercontent.com/u/20337240?s=460&v=4" align="left" hspace="10px" vspace="0px">
# </div>
# <h1>AI สัญชาติไทย</h1>
#
# <h1>ตัวอย่างโค้ด การใช้แพลตฟอร์มบริการเทคโนโลยีปัญญาประดิษฐ์</h1>
# <h2>ของดีจากทาง Nectec</h2>
#
# <font color='red'>เนือหาจะอัพเดตไปเรื่อยๆ แล้วแต่ละอารมณ์ (ยังไม่เสร็จดี)</font>
# <hr>
#
# <a href='https://www.facebook.com/programmerthai'><font color='green'>สรุปและเรียบเรียงโดย โปรแกรมเมอร์ไทย thai programmer</font></a>

# %% [markdown]
# ที่มาโค้ดทั้งหมดอ้างอิงมาจากตัวอย่างการใช้แพลทฟอร์มของทาง Nectec
#
# * https://www.aiforthai.in.th
#
# * https://www.youtube.com/playlist?list=PLoa6MvCfmUISHSoj98ruK1NkpKupmpIkk
#
# * https://www.facebook.com/groups/329293231118737/
#
#
# การใช้งานจะผ่านเว็บเซอร์วิส method เป็น GET หรือ POST
#
# ดังนั้นจึงสามารถเขียนด้วยภาษาโปรแกรมมิ่งอะไรก็ได้ ไม่ว่าจะเป็น PHP, C, C++, C#, JavaScrit, Java, Kotlin, Swift, Visual Basic เป็นต้น
#
# แต่ในกรณียกตัวอย่างเป็นภาษา Python เท่านั้น

# %% [markdown]
# # วิธีใช้งาน colab
#
# Colab พัฒนาโดย google เป็นหน้าเว็บเอาไว้ใช้เขียนโค้ด python ได้ผ่านทางหน้าเว็บ และเชื่อมต่อกับ google drive ของเราก็ได้ด้วย ซึ่ง colab หน้านี้**ได้รวบรวมเนื้อหา Python ของม.ต้น** เอาไว้ แต่ก่อนอื่นอยากให้ดูวิธีการใช้งาน colab เสียก่อน
#
# <font color='red'>** ต้องมี Gmail และ google drive</font>
#
# <hr/>
#
# <h3>วิธี 1) กด "Open in playgrouhd"</h3>
# <div>
# <img height="200px" src="https://www.patanasongsivilai.com/blog/wp-content/uploads/2020/05/python_matayom_4.png" align="center" hspace="10px" vspace="0px">
#
#
# <hr/>
#
# <h3>วิธี 2) กด Save a copy in Drive ... เพื่อบันทึกไว้ google drive เครื่องเรา</h3>
#
# <img height="300px" src="https://www.patanasongsivilai.com/blog/wp-content/uploads/2019/11/python_matayom_1.png" align="center" hspace="10px" vspace="0px">
#
# <br/>
#
# <img height="200px" src="https://www.patanasongsivilai.com/blog/wp-content/uploads/2019/11/python_matayom_2.png" align="center" hspace="10px" vspace="0px">
#
# <hr/>
#
# <h3>จากนั้นถึงจะสามารถรันได้</h3>
# <img height="200px" src="https://www.patanasongsivilai.com/blog/wp-content/uploads/2019/11/python_matayom_3.png" align="center" hspace="10px" vspace="0px">

# %% [markdown]
# # ต้องไปสมัครเว็บก่อน
#
# ไปที่ลิงค์นี้ https://aiforthai.in.th
#
# เพื่อขอ API key ในการใช้งาน
#
# (อันนี้เป็น API key ของผม เอาไว้แสดงตัวอย่างเฉยๆ)

# %% [markdown]
# # Set Environment

# %% [markdown]
# นำเข้าโมดูล requests เพื่อเรียกใช้เว็บเซอร์วิสต่างๆ ได้

# %%
# import requests

# %% [markdown]
# **เตรียมฟังก์ชันสำหรับแสดงผล**

# %%
import PIL.Image 
# from IPython.display import display, Image
import IPython

def display_image(file_img, scale=1):
  im = PIL.Image .open(file_img)
  w, h = im.size  
  IPython.display.display(IPython.display.Image(filename=file_img ,width=int(w*scale), height=int(h*scale) ) )

# %% [markdown]
# **ดาวน์โหลด Font ไทย (เอาไว้ใช้แสดงผล)**

# %%
# !wget https://www.dropbox.com/s/yuq8b9k77urjfc7/THSarabunNew.zip?dl=0 -O /content/THSarabunNew.zip
# !unzip -o THSarabunNew.zip
# Out:
# --2020-05-21 09:31:14--  https://www.dropbox.com/s/yuq8b9k77urjfc7/THSarabunNew.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.1, 2620:100:601f:1::a27d:901
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/yuq8b9k77urjfc7/THSarabunNew.zip [following]
# --2020-05-21 09:31:14--  https://www.dropbox.com/s/raw/yuq8b9k77urjfc7/THSarabunNew.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc7cb2134cf67da63ce8c149abd2.dl.dropboxusercontent.com/cd/0/inline/A4IFz5EEYQrrp-mP3BYPy1-ZXmeRKe3T8RgBL9eFK2RrJ2H4hENMf3m0kaYKOsWXNdbjKmbx7RLc8Bx9s7yd3B63rtG4DEerO3HXxUOXjwR0Nw/file# [following]
# ...

# %% [markdown]
# **ฟังก์ชันสำหรับพล็อตกราฟแท่ง**

# %%
import os
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import font_manager as fm, rcParams

def plot_bargraph(label_words, score_list, title=""):
  x = np.arange(len(label_words))  # the label locations
  width = 0.35  # the width of the bars
  
  fpath = os.path.join(rcParams["datapath"], "/content/THSarabunNew Bold.ttf")
  prop = fm.FontProperties(fname=fpath, size=18)
  fig, ax = plt.subplots()
  #rects1 = ax.bar(x - width/2, score_list, width, label='คำ', fontproperties=prop)
  rects1 = ax.bar(x - width/2, score_list, width)

  fig = plt.figure(figsize=(300, 300))

  # Add some text for labels, title and custom x-axis tick labels, etc.
  ax.set_ylabel('คะแนน', fontproperties=prop)
  ax.set_title(title, fontproperties=prop)
  ax.set_xticks(x)
  ax.set_xticklabels(label_words, fontproperties=prop)
  ax.legend()

  def autolabel(rects):
      """Attach a text label above each bar in *rects*, displaying its height."""
      for rect in rects:
          height = rect.get_height()
          ax.annotate('{:0.2f}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

  autolabel(rects1)
  fig.tight_layout()
  plt.show()

# %matplotlib inline

# %% [markdown]
# **ฟังก์ชั่นเอาไว้สำหรับอัดเสียงพูดภายไมค์โครโฟน**
#
# ที่มาโค้ด https://gist.github.com/korakot/c21c3476c024ad6d56d5f48b0bca92be

# %%
# all imports
from IPython.display import Javascript
from google.colab import output
from base64 import b64decode
from io import BytesIO
# !pip -q install pydub
from pydub import AudioSegment

RECORD = """
const sleep  = time => new Promise(resolve => setTimeout(resolve, time))
const b2text = blob => new Promise(resolve => {
  const reader = new FileReader()
  reader.onloadend = e => resolve(e.srcElement.result)
  reader.readAsDataURL(blob)
})
var record = time => new Promise(async resolve => {
  stream = await navigator.mediaDevices.getUserMedia({ audio: true })
  recorder = new MediaRecorder(stream)
  chunks = []
  recorder.ondataavailable = e => chunks.push(e.data)
  recorder.start()
  await sleep(time)
  recorder.onstop = async ()=>{
    blob = new Blob(chunks)
    text = await b2text(blob)
    resolve(text)
  }
  recorder.stop()
})
"""

def record(sec=3):
  global audio_file
  display(Javascript(RECORD))
  s = output.eval_js('record(%d)' % (sec*1000))
  b = b64decode(s.split(',')[1])
  with open(audio_file,'wb') as f:
    f.write(b)
  return audio_file

# %% [markdown]
# # CONVERSATION: พาที (Partii)
#
# Partii หรือ พาที คือ "ระบบรู้จำเสียงพูดภาษาไทย" หรือบางทีเรียกว่า ระบบแปลงเสียงพูดเป็นข้อความสำหรับภาษาไทย

# %%
#@title กรอกข้อมูล เพื่อกำหนดค่าให้กับตัวแปร
Apikey = "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w" #@param {type:"string"}
url_partii = "https://api.aiforthai.in.th/partii-webapi" #@param {type:"string"}
audio_file = "test_example.wav" #@param {type:"string"}

# %% [markdown]
# **เริ่มทำการบันทึกเสียง**

# %%
print("ลองพูดอะไรก็ได้ใส่ไมค์ดังๆ ขอให้ชัดเจน และเป็นประโยคเข้าใจง่าย เป็นเวลา 15 วินาที")
record(sec=15)
from IPython.display import Audio

print("คลิกเพื่อเปิดฟังเสียงที่ได้บันทึกไว้\n")
Audio(audio_file)
# Out:
# ลองพูดอะไรก็ได้ใส่ไมค์ดังๆ ขอให้ชัดเจน และเป็นประโยคเข้าใจง่าย เป็นเวลา 15 วินาที
# คลิกเพื่อเปิดฟังเสียงที่ได้บันทึกไว้
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import requests
 
# url = "https://api.aiforthai.in.th/partii-webapi"
url = url_partii

files = {'wavfile': open(audio_file, 'rb')}
 
headers = {
    'Apikey': Apikey,
    'Cache-Control': "no-cache",
    'Connection': "keep-alive",
    }
 
param = {"format":"json"}
 
response = requests.request("POST", url, headers=headers, files=files, data=param)
 
print("Result = " + response.text)
# Out:
# Result = {"status":"fail","result":"Invalid file type!!!"}

# %% [markdown]
# <pre>
# OUTPUT
# ผลลัพธ์ที่ได้จาก ระบบรู้จำเสียงพูดภาษาไทย (พาที) จะอยู่ในรูปแบบของ JSON Arrays จะมี 2 องค์ประกอบคือ
#
# result : เป็นข้อความที่ได้จากการผลวิเคราะห์เสียงพูดภาษาไทย
# status : สถานะของผลการวิเคราะห์ที่ได้ เป็น "success" หรือ "fail"</pre>

# %% [markdown]
# ผลการทำงานอาจผิดพลาด (รอทีมผู้พัฒนาปรับปรุง)

# %%
json_data = response.json()
if json_data['status'] == 'success':
  print("คุณพูดว่า:")
  print(json_data['result'])  
else:
  print("ไม่สามารถแปลงเสียงเป็นข้อความ")
# Out:
# ไม่สามารถแปลงเสียงเป็นข้อความ

# %% [markdown]
# # CONVERSATION : Vaja วาจา
#
# **บริการแปลงข้อความภาษาไทยให้เป็นเสียงพูด**

# %%
#@title กรอกข้อมูล เพื่อกำหนดค่าให้กับตัวแปร
Apikey = "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w" #@param {type:"string"}
url_vaja = "https://api.aiforthai.in.th/vaja" #@param {type:"string"}
text_vaja = "\u0E2A\u0E27\u0E31\u0E2A\u0E14\u0E35\u0E04\u0E23\u0E31\u0E1A \u0E17\u0E33\u0E2D\u0E30\u0E44\u0E23\u0E2D\u0E22\u0E39\u0E48\u0E40\u0E2B\u0E23\u0E2D" #@param {type:"string"}

# %%
import requests
 
# Apikey='BghsplRaCk6QRBZR5fX7krSjOdn1RS0w'
 
# url = 'https://api.aiforthai.in.th/vaja'
url = url_vaja

headers = {'Apikey':Apikey,'Content-Type' : 'application/x-www-form-urlencoded'}
 
# text = 'ข้อความที่ต้องการแปลง'
text = text_vaja

params = {'text':text,'mode':'st'}
 
# sending post request and saving response as response object
response = requests.get(url, params=params, headers=headers)
 
print(response.json())
# Out:
# {'output': {'mode': 'st', 'result': 'null'}, 'return': {'massage': '', 'status': 'error'}}

# %% [markdown]
# บางครั้งอาจเห็นการทำงานผิดพลาด (รอผู้พัฒนาระบบปรับปรุง)

# %%
result = response.json()['output']['audio']['result']
numChannels =response.json()['output']['audio']['numChannels']
validBits = response.json()['output']['audio']['validBits']
sizeSample=response.json()['output']['audio']['sizeSample']
sampleRate=response.json()['output']['audio']['sampleRate']
len(result), numChannels, validBits, sizeSample,sampleRate
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-cc284aee855e> in <module>()
# ----> 1 result = response.json()['output']['audio']['result']
#       2 numChannels =response.json()['output']['audio']['numChannels']
#       3 validBits = response.json()['output']['audio']['validBits']
#       4 sizeSample=response.json()['output']['audio']['sizeSample']
#       5 sampleRate=response.json()['output']['audio']['sampleRate']
#
# KeyError: 'audio'

# %% [markdown]
# <pre>
# ผลลัพธ์ที่ได้จาก ระบบสังเคราะห์เสียงพูดภาษาไทย "วาจา" จะอยู่ในรูปแบบของ JSON Arrays จะมีองค์ประกอบดังนี้
#
# output
#  audio (เฉพาะ mode 'st')
#  mode : st
#  numChannels: mono
#  result: Array of wave data
#  sizeSample: ชนิด integer
#  type: wav
#  validBits: 16
# return
#  massage : 0 หรือ 1
#  status: "success" หรือ "error"
#  </pre>

# %% [markdown]
# **เอาผลลัพธ์ที่ได้มาแปลงเป็นเสียง**

# %%
import wave, struct
 
obj = wave.open('sound.wav','wb') 
obj.setparams((1, int(validBits/8), sampleRate, 0, 'NONE', 'not compressed'))
for i in range(sizeSample):
  value = int(result[i])
  data = struct.pack('<h', value)  
  obj.writeframesraw(data)
obj.close()

print("คลิกเพื่อฟังเสียงได้เลย\n")
from IPython.display import Audio
Audio('/content/sound.wav')

# %% [markdown]
# **ดาวน์โหลดโฟล์เสียงที่สังเคราะห์ได้มาเก็บที่เครื่องเรา**

# %%
from google.colab import files
files.download('sound.wav')

# %% [markdown]
# #Basic NLP : Word Similarity
#
# โปรแกรมแนะนำคำที่สะกดใกล้เคียง ผู้ใช้สามารถค้นหาคำที่ใกล้เคียงกันในพจนานุกรมคำศัพท์
#
# ได้แก่ พจนานุกรมราชบัณฑิตยสถาน, รายชื่อคนไทยยอดนิยม, รายชื่ออาหารไทย และรายชื่อสถานที่ (ตำบล, อำเภอ, จังหวัด)

# %%
#@title กรอกข้อมูล เพื่อกำหนดค่าให้กับตัวแปร
Apikey = "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w" #@param {type:"string"}
url_wordapprox = "https://api.aiforthai.in.th/wordapprox" #@param {type:"string"}
text_wordapprox = "\u0E07\u0E32\u0E19\u0E2B\u0E21\u0E31\u0E49\u0E19" #@param {type:"string"}
model = "royin " #@param {type:"string"}

# %%
import requests
 
# url = "https://api.aiforthai.in.th/wordapprox"
url = url_wordapprox
text = text_wordapprox

params = {'word':text,'model': model}
 
headers = {
    'Apikey': "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w",
    }
 
response = requests.request("GET", url, headers=headers, params=params)
 
print(response.json())
# Out:
# {'words': [{'distance': 0.8880952380952382, 'word': 'งานหนัก'}, {'distance': 0.8678571428571429, 'word': 'งานหลัก'}, {'distance': 0.8541666666666666, 'word': 'งาน'}, {'distance': 0.8366666666666667, 'word': 'งานหนังสือ'}, {'distance': 0.8333333333333334, 'word': 'ทองหมั้น'}, {'distance': 0.8333333333333334, 'word': 'ถอนหมั้น'}, {'distance': 0.8333333333333334, 'word': 'ของหมั้น'}]}

# %% [markdown]
# <pre>
# OUTPUT
# ผลลัพธ์ที่ได้จากโปรแกรมแนะนำคำที่สะกดใกล้เคียงโปรแกรมแนะนำคำที่สะกดใกล้เคียงจะอยู่ในรูปแบบของ JSON จะมีองค์ประกอบดังนี้
# words : ผลลัพธ์ของคำทั้งหมดและคะแนนความใกล้เคียง
#  distance : คะแนนความใกล้เคียง
#  word : คำที่ใกล้เคียง</pre>

# %% [markdown]
# **แสดงผลคำคล้าย**

# %%
data_json = response.json()

for result in data_json['words']:
    print("'%s' มีคะแนนความคล้าย=%f" % (result['word'],result['distance']) )
# Out:
# 'งานหนัก' มีคะแนนความคล้าย=0.888095
# 'งานหลัก' มีคะแนนความคล้าย=0.867857
# 'งาน' มีคะแนนความคล้าย=0.854167
# 'งานหนังสือ' มีคะแนนความคล้าย=0.836667
# 'ทองหมั้น' มีคะแนนความคล้าย=0.833333
# 'ถอนหมั้น' มีคะแนนความคล้าย=0.833333
# 'ของหมั้น' มีคะแนนความคล้าย=0.833333

# %% [markdown]
# **แสดงผลในรูปกราฟแท่ง**

# %%
data_json = response.json()

label_words =[]
score_list = []
for result in data_json['words']:
    label_words.append(result['word'])
    score_list.append( result['distance'])

print("คำที่เกี่ยวข้องและความหมายใกล้เคียงกันของ '%s'" % text)
plot_bargraph(label_words, score_list , title=text)
# Out:
# No handles with labels found to put in legend.
# คำที่เกี่ยวข้องและความหมายใกล้เคียงกันของ 'งานหมั้น'

# %% [markdown]
# # Basic NLP : Word Similarity
#
# โปรแกรมแนะนำคำที่เกี่ยวข้องและความใกล้เคียงกันจากคลังข้อมูลวิกิพีเดียภาษาไทยและทวิตเตอร์ภาษาไทย

# %%
#@title กรอกข้อมูล เพื่อกำหนดค่าให้กับตัวแปร
Apikey = "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w" #@param {type:"string"}
url_thaiwordsim = "https://api.aiforthai.in.th/thaiwordsim" #@param {type:"string"}
text_thaiwordsim = "\u0E1B\u0E48\u0E32\u0E44\u0E21\u0E49" #@param {type:"string"}

# %%
import requests
 
#url = "https://api.aiforthai.in.th/thaiwordsim"
url = url_thaiwordsim
text = text_thaiwordsim

params = {'word':text,'model':'thwiki','numword':'5'}
 
headers = {
    'Apikey': Apikey,
    }
 
response = requests.get(url, headers=headers, params=params)
 
print(response.text)
# Out:
# {"words":[{"score":0.6940796971321106,"word":"ต้นน้ำลำธาร"},{"score":0.6862344741821289,"word":"ของป่า"},{"score":0.6820991635322571,"word":"อุดมสมบูรณ์"},{"score":0.6475814580917358,"word":"ป่า"},{"score":0.6209665536880493,"word":"พืชพรรณ"}]}

# %% [markdown]
# <pre>
# OUTPUT
# ผลลัพธ์ที่ได้จากระบบตัดคําภาษาไทยเล็กซ์โต จะอยู่ในรูปแบบของ JSON จะมีองค์ประกอบดังนี้
# words : ชุดคำที่ได้
#  score : คะแนนความคล้าย
#  word : คำที่ใกล้เคียง
# </pre>

# %% [markdown]
# **แสดงผลคำคล้าย**

# %%
data_json = response.json()

for result in data_json['words']:
    print("'%s' มีคะแนนความคล้าย=%f" % (result['word'],result['score']) )
# Out:
# 'ต้นน้ำลำธาร' มีคะแนนความคล้าย=0.694080
# 'ของป่า' มีคะแนนความคล้าย=0.686234
# 'อุดมสมบูรณ์' มีคะแนนความคล้าย=0.682099
# 'ป่า' มีคะแนนความคล้าย=0.647581
# 'พืชพรรณ' มีคะแนนความคล้าย=0.620967

# %% [markdown]
# **แสดงผลในรูปกราฟแท่ง**

# %%
data_json = response.json()

label_words =[]
score_list = []
for result in data_json['words']:
    label_words.append(result['word'])
    score_list.append( result['score'])

print("คำที่เกี่ยวข้องและความหมายใกล้เคียงกันของ '%s'" % text)
plot_bargraph(label_words, score_list , title=text)
# Out:
# No handles with labels found to put in legend.
# คำที่เกี่ยวข้องและความหมายใกล้เคียงกันของ 'ป่าไม้'

# %% [markdown]
# # LANGUAGE : MACHINE TRANSLATION
#
# **บริการแปลภาษา**

# %% [markdown]
# ระบบแปลภาษาด้วยเครื่อง ( เสี่ยวฟ่าน: Xiaofan) โดยใช้แนวทางระบบแปลภาษาแบบประสาทเทียมและตัวแบบจำลองทวิน: ใช้สำหรับแปลภาษา
#
# * แปลจากไทยไปจีนใช้ url https://api.aiforthai.in.th/th-zh-nmt/
#
# * แปลจากจีนไปไทยใช้ url https://api.aiforthai.in.th/zh-th-nmt/
#
# * แปลจากอังกฤษไปใช้ url https://api.aiforthai.in.th/xiaofan-en-th/

# %%
#@title กรอกข้อมูล เพื่อกำหนดค่าให้กับตัวแปร
Apikey = "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w" #@param {type:"string"}
url_translator = "https://api.aiforthai.in.th/th-zh-nmt/" #@param {type:"string"}
text_translator = "\u0E2A\u0E27\u0E31\u0E2A\u0E14\u0E35\u0E04\u0E19\u0E08\u0E35\u0E19 \u0E04\u0E19\u0E08\u0E35\u0E19\u0E2B\u0E19\u0E49\u0E32\u0E23\u0E31\u0E01" #@param {type:"string"}

# %%
import requests
from urllib.parse import quote_plus
 
# text = 'สวัสดี'
 
# url = 'https://api.aiforthai.in.th/th-zh-nmt/' +quote_plus(text)
url = url_translator
text = text_translator

url = url + quote_plus(text)

headers = {
    'Apikey': Apikey,
    }
 
response = requests.get(url, headers=headers)
 
print(response.text) # ผลลัพธ์ของการแปลภาษา
# Out:
# 你好我是中国人

# %%
print("'%s' แปลเป็นภาษาจีนว่า '%s'" % (text, response.text))
# Out:
# 'สวัสดีคนจีน คนจีนหน้ารัก' แปลเป็นภาษาจีนว่า '你好我是中国人'

# %% [markdown]
# # LANGUAGE : SENTIMENT ANALYSIS
#
# **บริการวิเคราะห์ความคิดเห็นและอารมณ์ (Ssense)**

# %% [markdown]
# ## ไทยโมจิ (ThaiMoji)
#
# ThaiMoji เป็นเครื่องมือตรวจจับ Emotion หรือ Character ของข้อความแล้ว แสดงผลคืนเป็น สัญลักษณ์ emoji เพื่อเพิ่มให้ข้อความสื่อถึงอารมณ์และ ความรู้สึกของผู้เขียนได้ชัดเจนขึ้นทั้งนี้ยังสามารถประยุกต์ใช้งานตามประเภทของ emoji เพื่อสกัดการความรู้สึกของข้อความที่ติด hashtag ต่างๆ ได้อีกด้วย

# %%
#@title กรอกข้อมูล เพื่อกำหนดค่าให้กับตัวแปร
Apikey = "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w" #@param {type:"string"}
url_emojj = "https://api.aiforthai.in.th/emoji" #@param {type:"string"}
text_emojj = "\u0E0A\u0E2D\u0E1A\u0E41\u0E1A\u0E1A\u0E19\u0E35\u0E49 \u0E0A\u0E2D\u0E1A\u0E17\u0E35\u0E48\u0E40\u0E1B\u0E47\u0E19\u0E41\u0E1A\u0E1A\u0E19\u0E35\u0E49 \u0E0A\u0E2D\u0E1A\u0E41\u0E27\u0E27\u0E15\u0E32\u0E41\u0E1A\u0E1A\u0E19\u0E35\u0E49 \u0E0A\u0E2D\u0E1A\u0E23\u0E2D\u0E22\u0E22\u0E34\u0E49\u0E21\u0E41\u0E1A\u0E1A\u0E19\u0E35\u0E49 \u0E01\u0E47\u0E0A\u0E2D\u0E1A\u0E04\u0E19\u0E19\u0E35\u0E49 " #@param {type:"string"}

# %%
import requests
 
moji_list =[['🙂','😄','😁','😆','😀','😊','😃'],
['😢','😥','😰','😓','🙁','😟','😞','😔','😣','😫','😩'],
['😡','😠','😤','😖'],
['🙄','😒','😑','😕'],
['😱'],
['😨','😧','😦'],
['😮','😲','😯'],
['😴','😪'],
['😋','😜','😝','😛'],
['😍','💕','😘','😚','😙','😗'],
['😌'],
['😐'],
['😷'],
['😳'],
['😵'],
['💔'],
['😎','😈'],
['🙃','😏','😂','😭'],
['😬','😅','😶'],
['😉'],
['💖','💙','💚','💗','💓','💜','💘','💛'],
['😇']]
 
#url = "https://api.aiforthai.in.th/emoji"
url = url_emojj

#text = 'ความรักเป็นสิ่งสวยงาม'
text = text_emojj
 
params = {'text':text}
 
headers = {
    'Apikey': Apikey
    }
 
response = requests.get(url, params=params, headers=headers)
 
keys=response.json().keys()

emoji = [moji_list[int(k)][0] for k in keys]
 
print(emoji)
print(response.json())
# Out:
# ['🙂', '😍', '💖']
# {'0': '0.23338024', '9': '0.37830898', '20': '0.39032105'}

# %% [markdown]
# ผลลัพธ์ที่ได้จะอยู่ในรูปแบบของ JSON Arrays ซึ่งอาเรย์จะประกอบด้วย array ของ emoji ผลลัพธ์และคะแนนของ emoji นั้นๆ (สามารถดูรูป emoji ของแต่ละคลาสได้จากตารางด้านล่าง)
#
# <pre>
# {
#     "0": "0.18169652",
#     "9": "0.31355354",
#     "20": "0.40911666"
# }</pre>
#
# <img src="https://aiforthai.in.th/images/thaimoji.png" width="50%"/>

# %% [markdown]
# ## เอสเซนส์ ระบบวิเคราะห์ความคิดเห็นจากข้อความ (Social Sensing: SSENSE)
#
# ระบบวิเคราะห์ความคิดเห็นข้อความภาษาไทย โดยวิเคราะห์ในเชิงจุดประสงค์ ของข้อความ (Intention) ว่าเป็นประเภทใด ได้แก่ สอบถาม ร้องขอ ประกาศ โฆษณา และ/หรือแสดงความคิดเห็น วิเคราะห์ความคิดเห็น (Sentiment) ว่า เป็นเชิงบวกหรือลบ รวมทั้งวิเคราะห์คําบ่งบอกคุณลักษณะของสินค้าหรือ บริการ (Feature words) ด้วย

# %%
#@title กรอกข้อมูล เพื่อกำหนดค่าให้กับตัวแปร
Apikey = "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w" #@param {type:"string"}
url_ssense = "https://api.aiforthai.in.th/ssense" #@param {type:"string"}
text_ssense = "\u0E04\u0E19\u0E44\u0E17\u0E22\u0E19\u0E48\u0E32\u0E23\u0E31\u0E01\u0E14\u0E35" #@param {type:"string"}

# %%
import requests
 
#url = "https://api.aiforthai.in.th/ssense"
 
#text = 'สาขานี้พนักงานน่ารักให้บริการดี'
url = url_ssense
text = text_ssense

data = {'text':text}
 
headers = {
    'Apikey': "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w"
    }
 
response = requests.post(url, data=data, headers=headers)
 
print(response.json())
# Out:
# {'sentiment': {'score': '75', 'polarity-neg': False, 'polarity-pos': True, 'polarity': 'positive'}, 'preprocess': {'input': 'คนไทยน่ารักดี', 'neg': [], 'pos': ['น่ารักดี'], 'segmented': ['คนไทย', 'น่ารักดี'], 'keyword': ['คนไทย']}, 'alert': [], 'comparative': [], 'associative': [], 'intention': {'request': '0', 'sentiment': '75', 'question': '0', 'announcement': '0'}}

# %% [markdown]
# <pre>
# OUTPUT
# ผลลัพธ์ที่ได้จาก ระบบ SSense จะอยู่ในรูปแบบของ JSON Arrays ซึ่งแต่ละอาเรย์จะมีองค์ประกอบดังนี้
#
# sentiment : ผลวิเคราะห์ความคิดเห็นว่าเป็นเชิงบวกหรือลบ
#  polarity : ขั้วอารมณ์ความคิดเห็น (positive: เชิงบวก, negative: เชิงลบ, ค่าว่าง: ไม่เป็นทั้งบวกและลบ)
#  polarity-pos : มีข้อความเชิงบวกใช่หรือไม่ (true=ใช่, false =ไม่ใช่)
#  polarity-neg : มีข้อความเชิงบวกใช่หรือไม่ (true=ใช่, false =ไม่ใช่)
#  score : ร้อยละคะแนนความมั่นใจ (confidence)
# intention : ผลวิเคราะห์จุดประสงค์ของข้อความ
#  sentiment : ร้อยละคะแนนความมั่นใจ (confidence)ว่าเป็นข้อความแสดงความคิดเห็น
#  announcement : ร้อยละคะแนนความมั่นใจ (confidence) ว่าเป็นข้อความประกาศหรือโฆษณา
#  request : ร้อยละคะแนนความมั่นใจ (confidence) ว่าเป็นข้อความในเชิงร้องขอ
#  question : ร้อยละคะแนนความมั่นใจ (confidence) ว่าเป็นข้อความในเชิงคําถาม
# preprocess : ผลลัพธ์การจัดการข้อความก่อนวิเคราะห์
#  input : ข้อความที่นําเข้าไปวิเคราะห์
#  neg : คำที่แสดงเชิงลบ
#  pos : คำที่แสดงเชิงบวก
#  keyword : array ของคําสําคัญ
#  segmented : array ของคําที่ได้จากการตัดคํา input
# alert : array ของข้อความที่แสดงการแจ้งเตือน
# comparative: ผลวิเคราะห์ข้อความที่มีการเปรียบเทียบแบรนด์/สินค้า
#  text : ข้อความที่แสดงการเปรียบเทียบ
#  ent-pos : แบรนด์ที่ถูกวิเคราะห์ว่าเป็นเชิงบวก
#  ent-neg : แบรนด์ที่ถูกวิเคราะห์ว่าเป็นเชิงลบ
#  polarity-pos : เป็นข้อความเชิงบวกใช่หรือไม่ (true=ใช่, false =ไม่ใช่)
#  polarity-neg - beginIndex - endIndex: เป็นข้อความเชิงบวกใช่หรือไม่ (true=ใช่, false =ไม่ใช่)
#  beginIndex : ตําแหน่งอักขระแรกของข้อความที่แสดงการเปรียบเทียบ
#  endIndex : ตําแหน่งอักขระสุดท้ายของข้อความที่แสดงการเปรียบเทียบ
#  asp : array ของคําคุณลักษณะ (feature word)
# associative: ผลวิเคราะห์ข้อความที่มีความคิดเห็นต่อแบรนด์/สินค้า
#  text : ข้อความที่แสดงการเปรียบเทียบ
#  ent-pos : แบรนด์ที่ถูกวิเคราะห์ว่าเป็นเชิงบวก
#  ent-neg : แบรนด์ที่ถูกวิเคราะห์ว่าเป็นเชิงลบ
#  polarity-pos : เป็นข้อความเชิงบวกใช่หรือไม่ (true=ใช่, false =ไม่ใช่)
#  polarity-neg - beginIndex - endIndex: เป็นข้อความเชิงบวกใช่หรือไม่ (true=ใช่, false =ไม่ใช่)
#  beginIndex : ตําแหน่งอักขระแรกของข้อความที่แสดงการเปรียบเทียบ
#  endIndex : ตําแหน่งอักขระสุดท้ายของข้อความที่แสดงการเปรียบเทียบ
#  asp : array ของคําคุณลักษณะ (feature word)
#
# </pre>

# %% [markdown]
# # LANGUAGE : Tag Suggestion
#
# บริการแนะนำป้ายกำกับที่เกี่ยวข้องกับเนื้อหา

# %%
#@title กรอกข้อมูล เพื่อกำหนดค่าให้กับตัวแปร
Apikey = "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w" #@param {type:"string"}
url_tag = "https://api.aiforthai.in.th/tagsuggestion" #@param {type:"string"}
text_tag = "\u0E40\u0E28\u0E23\u0E29\u0E10\u0E01\u0E34\u0E08\u0E1B\u0E23\u0E30\u0E40\u0E17\u0E28\u0E44\u0E17\u0E22\u0E08\u0E30\u0E40\u0E08\u0E23\u0E34\u0E0D" #@param {type:"string"}

# %%
import requests
 
# url = "https://api.aiforthai.in.th/tagsuggestion"
url = url_tag

# text = 'ข้าวและแป้งมีสารอาหารหลักคือคาร์โบไฮเดรต'
text = text_tag

params = {'text':text,'numtag':'5'}
 
headers = {
    'Apikey': Apikey,
    }
 
response = requests.get( url, headers=headers, params=params)
 
print(response.json())
# Out:
# {'tags': [{'score': 1, 'tag': 'เศรษฐกิจ'}, {'score': 0.7666666666666666, 'tag': 'ประเทศไทย'}, {'score': 0.39999999999999997, 'tag': 'การเมืองท้องถิ่น'}, {'score': 0.26666666666666666, 'tag': 'การเมือง'}, {'score': 0.26666666666666666, 'tag': 'เศรษฐศาสตร์'}]}

# %% [markdown]
# <pre>
# OUTPUT
# ผลลัพธ์ที่ได้จากระบบแนะนําป้ายกํากับ ( Tag suggestion ) จะอยู่ในรูปแบบของ JSON มีตัวอย่างดังนี้
#
# score: ค่าน้ำหนักของแท็ก
# tag: คำ(แท็ก)ที่แนะนำ
# </pre>

# %% [markdown]
# **แสดงผลการติด tags ข้อความ**

# %%
json_data = response.json()
tags = json_data['tags']

print("ข้อความ: ", text)
for t in tags:
  print('tag = %s ,score = %s' % (t['tag'],t['score']))
# Out:
# ข้อความ:  เศรษฐกิจประเทศไทยจะเจริญ
# tag = เศรษฐกิจ ,score = 1
# tag = ประเทศไทย ,score = 0.7666666666666666
# tag = การเมืองท้องถิ่น ,score = 0.39999999999999997
# tag = การเมือง ,score = 0.26666666666666666
# tag = เศรษฐศาสตร์ ,score = 0.26666666666666666

# %% [markdown]
# **แสดงผลในรูปกราฟแท่ง**

# %%
data_json = response.json()

label_tags =[]
score_list = []
for result in data_json['tags']:
    label_tags.append(result['tag'])
    score_list.append( result['score'])

print("tags ของ '%s' สามารถนำไปพล็อตกรฟดังนี้" % text)
plot_bargraph(label_tags, score_list , title=text)
# Out:
# No handles with labels found to put in legend.
# tags ของ 'เศรษฐกิจประเทศไทยจะเจริญ' สามารถนำไปพล็อตกรฟดังนี้

# %% [markdown]
# # VISION : Person Detection

# %% [markdown]
# ## Person Detection (T-Person) บริการระบุตำแหน่งบุคคลในภาพ
#
# ระบบระบุตำแหน่งบุคคลในภาพ โดยอาจเป็นภาพของบุคคลเพียงคนเดียวหรือภาพของกลุ่มบุคคลก็ได้

# %%
#@title กรอกข้อมูล เพื่อกำหนดค่าให้กับตัวแปร
Apikey = "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w" #@param {type:"string"}
url_tperson = "https://api.aiforthai.in.th/person/human_detect/" #@param {type:"string"}
image_person = "image.jpg" #@param {type:"string"}

# %% [markdown]
# **ดาวน์โหลดภาพตัวอย่าง**

# %%
# !wget https://raw.githubusercontent.com/adminho/machine-learning/master/Datasets/example_detect_object.jpg -O image.jpg
# Out:
# --2020-04-30 07:53:51--  https://raw.githubusercontent.com/adminho/machine-learning/master/Datasets/example_detect_object.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 868503 (848K) [image/jpeg]
# Saving to: ‘image.jpg’
#
# image.jpg           100%[===================>] 848.15K  --.-KB/s    in 0.04s
#
# 2020-04-30 07:53:51 (18.9 MB/s) - ‘image.jpg’ saved [868503/868503]

# %%
# หรือจะอัพโหลดไฟล์ขึ้นคลาวด์ด้วยโค้ดชุดนี้
'''
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
'''
# Out:
# '\nfrom google.colab import files\n\nuploaded = files.upload()\n\nfor fn in uploaded.keys():\n  print(\'User uploaded file "{name}" with length {length} bytes\'.format(\n      name=fn, length=len(uploaded[fn])))\n'

# %% [markdown]
# **แสดงตัวอย่างภาพต้นฉบับ**

# %%
display_image(image_person, 0.3)

# %% [markdown]
# **เรียกใช้ API**

# %%
import requests
 
# url = "https://api.aiforthai.in.th/person/human_detect/"
url = url_tperson

files = {'src_img':open(image_person, 'rb')}
 
data = {'json_export':'true','img_export':'true'}
 
headers = {
    'Apikey': Apikey
    }
 
response = requests.post(url, files=files, headers=headers, data=data)
 
print(response.json())
# Out:
# {'json_data': [{'object': 'person', 'x0': 492, 'y0': 642, 'x1': 704, 'y1': 1232}, {'object': 'person', 'x0': 1603, 'y0': 678, 'x1': 1739, 'y1': 1019}, {'object': 'person', 'x0': 135, 'y0': 674, 'x1': 338, 'y1': 1222}, {'object': 'person', 'x0': 1481, 'y0': 658, 'x1': 1615, 'y1': 1012}, {'object': 'person', 'x0': 1275, 'y0': 694, 'x1': 1432, 'y1': 1206}, {'object': 'person', 'x0': 863, 'y0': 662, 'x1': 926, 'y1': 874}, {'object': 'person', 'x0': 984, 'y0': 664, 'x1': 1049, 'y1': 856}, {'object': 'person', 'x0': 1127, 'y0': 654, 'x1': 1188, 'y1': 832}, {'object': 'person', 'x0': 287, 'y0': 653, 'x1': 397, 'y1': 997}, {'object': 'person', 'x0': 921, 'y0': 664, 'x1': 979, 'y1': 865}, {'object': 'person', 'x0': 1031, 'y0': 656, 'x1': 1102, 'y1': 858}, {'object': 'person', 'x0': 1189, 'y0': 663, 'x1': 1251, 'y1': 821}], 'human_img': 'http://api.aiforthai.in.th/person-image/image/?code=1588233239988_human.jpg'}

# %% [markdown]
# <pre>
# OUTPUT
# ผลลัพธ์ที่ได้จาก ระบบระบุตำแหน่งบุคคลในภาพจะอยู่ในรูปแบบของ JSON Arrays ตามจำนวนคนที่พบในรูปภาพจะมีองค์ประกอบดังนี้
#
# json_data : ข้อมูลในรูปแบบ JSON (ถ้าเลือก)
#  object: person (ชนิดของ object)
#  x0: ตำแหน่งมุมซ้ายบนของกรอบสี่เหลี่ยมรอบตัวคน ในแนวแกน x
#  y0: ตำแหน่งมุมซ้ายบนของกรอบสี่เหลี่ยมรอบตัวคน ในแนวแกน y
#  x1: ตำแหน่งมุมขวาล่างของกรอบสี่เหลี่ยมรอบตัวคน ในแนวแกน x
#  y1: ตำแหน่งมุมขวาล่างของกรอบสี่เหลี่ยมรอบตัวคน ในแนวแกน y
# human_img : URL สำหรับการดาวน์โหลดรูปภาพ (ถ้าเลือก)</pre>

# %% [markdown]
# **แสดงผลตรวจจับคนในรูป**

# %%
json_data = response.json()
IPython.display.Image(url=json_data['human_img'] ,width=650)
# Out:
# <img src="http://api.aiforthai.in.th/person-image/image/?code=1588233239988_human.jpg" width="650"/>

# %% [markdown]
# ## ระบบบริการประเมินความหนาแน่นของบุคคลในการใช้พื้นที่ (Motion Heatmap)
#
# ระบบบริการประเมินความหนาแน่นของบุคคลในการใช้พื้นที่ (Motion Heatmap) เป็นการแปลงไฟล์ภาพของกลุ่มบุคคลไปเป็นไฟล์ภาพความร้อนซึ่งบอกความหนาแน่นของจุดที่มีบุคคลอยู่ในภาพ

# %%
#@title กรอกข้อมูล เพื่อกำหนดค่าให้กับตัวแปร
Apikey = "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w" #@param {type:"string"}
url_heatmap = "http://person-api.openservice.in.th/heat_detect/" #@param {type:"string"}
video_url = "https://youtu.be/FuZTpO4YDX8" #@param {type:"string"}
video_heatmap = "Tiki-Taka Thailand Football Tik Tok !!.mp4" #@param {type:"string"}
folder_frame = "output_video" #@param {type:"string"}

# %% [markdown]
# **ดาวน์โหลดไฟวีดีโอตัวอย่าง**

# %%
#!wget https://github.com/adminho/machine-learning/blob/master/Datasets/example_heat_detect.mp4?raw=true -O /content/example_heat_detect.mp4
# !pip -q install pytube3

import pytube
youtube = pytube.YouTube(video_url)
video = youtube.streams.first()
video.download('/content')
# Out:
# '/content/Tiki-Taka Thailand Football Tik Tok !!.mp4'

# %%
# หรือจะอัพโหลดไฟล์ขึ้นคลาวด์ด้วยโค้ดชุดนี้
'''
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
'''
# Out:
# '\nfrom google.colab import files\n\nuploaded = files.upload()\n\nfor fn in uploaded.keys():\n  print(\'User uploaded file "{name}" with length {length} bytes\'.format(\n      name=fn, length=len(uploaded[fn])))\n'

# %% [markdown]
# **แสดงตัวอย่างไฟล์วีดีโอ**

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open(video_heatmap,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=500 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# **สร้างโฟลเดอร์เก็บเฟรมรูปภาพจากวีดีโอ**

# %%
import shutil
import os

if os.path.isdir(folder_frame):
  shutil.rmtree(folder_frame)

os.mkdir(folder_frame)

# %% [markdown]
# **แยกเฟรมภาพจากวีดีโอ แล้วเก็บไว้ที่โฟลเดอร์ (ใช้เวลานานหน่อย)**

# %%
import os 
import cv2
import numpy as np

# Create a VideoCapture object and read from input file
# If the input is the camera, pass 0 instead of the video file name
cap = cv2.VideoCapture(video_heatmap)

# Check if camera opened successfully
if (cap.isOpened()== False): 
  print("Error opening video stream or file")
count=1
# Read until video is completed
while(cap.isOpened()):
  # Capture frame-by-frame
  ret, frame = cap.read()
  if ret == True:

    # Display the resulting frame
    cv2.imwrite(os.path.join(folder_frame ,"frame_%04d.jpg"%count) ,frame)
    count+=1    
  else: 
    break

# When everything done, release the video capture object
cap.release()

# Closes all the frames
cv2.destroyAllWindows()

# %% [markdown]
# เก็บเฟรมภาพต่างๆ ไว้ในลิสต์ แล้วจัดเรียงตามลำดับ
#
# จากนั้นจะเลือกเฉพาะบาง frame
#
# เพื่อไม่ให้เซอร์เวอร์วิสที่เรียกใช้ทำงานหนักเกินไป

# %%
list_frame = [f for f in os.listdir(folder_frame) if os.path.isfile(os.path.join(folder_frame,f)) and f.endswith(".jpg")]
list_frame.sort()
list_frame = list_frame[170:200]

# %% [markdown]
# **เรียกใช้ API (รอนานหน่อยเพราะมีหลายรูป)**

# %%
import requests
import json
 
# list of sequence images
#fname = ['heatmap-ex-1.jpg','heatmap-ex-2.jpg','heatmap-ex-3.jpg','heatmap-ex-4.jpg','heatmap-ex-5.jpg']
fname = list_frame
 
#url = 'http://person-api.openservice.in.th/heat_detect/'
#key = "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w"
url = url_heatmap
 
for i,f in enumerate(fname):
  f =os.path.join(folder_frame,f)
  if i%10 == 0: print('Process Request:',f) # แสดงสถานะทุกๆ 10 รอบ เพื่อประสิทธิภาพในการทำงาน
  headers = {
    #'apikey': key,
    'apikey': Apikey,
  }
  files = {
      'src_img': open(f, 'rb')
  }
  data   = {
      'json_export':'true',
      'img_export':'false'
  }
 
  if i>0:
    data['src_json'] = json.dumps(src_json) # send the returned json from the previous frame to update heatmap data
 
  if i==len(fname)-1:
    data['img_export'] = 'true' # set flag to get the heatmap image for the last request
 
  response = requests.post(url, data=data, files=files, headers=headers)
  src_json = response.json()
 
print(src_json['heat_img']) # print url for downloading the heatmap image
# Out:
# Process Request: output_video/frame_0171.jpg
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-146-8d9bc36d5c32> in <module>()
#      32
#      33   response = requests.post(url, data=data, files=files, headers=headers)
# ---> 34   src_json = response.json()
#      35
#      36 print(src_json['heat_img']) # print url for downloading the heatmap image
#
# /usr/local/lib/python3.6/dist-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# /usr/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
# ...

# %% [markdown]
# </pre>
# OUTPUT
# ผลลัพธ์ที่ได้จาก ระบบบริการประเมินความหนาแน่นของบุคคลในการใช้พื้นที่ (Motion Heatmap) จะอยู่ในรูปแบบของ JSON Arrays ตามจำนวนป้ายที่พบในรูปภาพ ซึ่งจะมีองค์ประกอบดังนี้
#
# param : ความกว้างของภาพ output, ความสูงของภาพ output, ความกว้างของขนาด grid, ความสูงของขนาด grid ] โดย grid คือ ช่องพื้นที่ย่อยสำหรับนับจำนวน
# data : จำนวนความหนาแน่นของคนในรูปแบบ grid โดยแสดงเป็นพิกัด (r,c) ของ grid และจำนวนคน (num) ใน grid นั้นๆ
#  r: ตำแหน่งแถวของ grid
#  c: ตำแหน่งคอลัมน์ของ grid
#  num: จำนวนความหนาแน่นของคนใน grid ที่ตำแหน่ง (r,c)
# heat_img : url สำหรับดาวน์โหลดรูปภาพ
# </pre>

# %% [markdown]
# **แสดงผลลัพธ์ Heatmap**

# %%
IPython.display.Image(url=src_json['heat_img'] ,width=650)

# %% [markdown]
# # VISION : Thai Food Recognition (T-Food)
#
# บริการระบุชื่ออาหารไทยจากรูปภาพ ด้วยเทคนิค Deep Learning

# %%
#@title กรอกข้อมูล เพื่อกำหนดค่าให้กับตัวแปร
Apikey = "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w" #@param {type:"string"}
url_thaifood = "https://api.aiforthai.in.th/thaifood" #@param {type:"string"}
image_thaifood = "test_thai_food.jpg" #@param {type:"string"}

# %% [markdown]
# **ดาวน์โหลดภาพอาหารไทยตัวอย่างจากอินเตอร์เนต**

# %%
# !wget https://img.theculturetrip.com/1024x/smart/wp-content/uploads/2017/12/7794345124_f48e5b469c_k.jpg -O /content/test_thai_food.jpg
# Out:
# --2020-04-30 08:22:10--  https://img.theculturetrip.com/1024x/smart/wp-content/uploads/2017/12/7794345124_f48e5b469c_k.jpg
# Resolving img.theculturetrip.com (img.theculturetrip.com)... 99.86.32.41, 99.86.32.117, 99.86.32.51, ...
# Connecting to img.theculturetrip.com (img.theculturetrip.com)|99.86.32.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 197397 (193K) [image/jpeg]
# Saving to: ‘/content/test_thai_food.jpg’
#
# /content/test_thai_ 100%[===================>] 192.77K  --.-KB/s    in 0.02s
#
# 2020-04-30 08:22:10 (7.56 MB/s) - ‘/content/test_thai_food.jpg’ saved [197397/197397]

# %%
# หรือจะอัพโหลดไฟล์ขึ้นคลาวด์ด้วยโค้ดชุดนี้
'''
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
'''

# %% [markdown]
# **แสดงภาพตัวอย่าง**

# %%
display_image(image_thaifood, scale=0.5)

# %% [markdown]
# **เรียกใช้ API**

# %%
#save image to base64
import base64
#b64file = open('food-ex.jpg', 'rb').read()
b64file = open(image_thaifood, 'rb').read()
imgData = base64.b64encode(b64file)
imgFile = open('food-ex.txt', 'wb')
imgFile.write(imgData)
imgFile.flush()
imgFile.close()
 
import requests
 
#url = "https://api.aiforthai.in.th/thaifood"
url = url_thaifood
 
data = {
  'file': open('food-ex.txt', 'r').read()
}
headers = {
	'Content-Type': 'application/json',
    #'Apikey': "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w",
    'Apikey': Apikey,
    }
 
response = requests.post(url, headers=headers, json=data)
 
print(response.json())
# Out:
# {'OK': True, 'filename': './uploads/2020/04/30/20200430152221.png', 'objects': [{'label': '(น่าจะ) ผัดหมี่ซั่วหมู', 'rank': '0', 'result': 'ผัดหมี่ซั่วหมู', 'score': '0.11271966'}]}

# %% [markdown]
# <pre>
# OUTPUT
# ผลลัพธ์ที่ได้จาก ระบบรู้จำอาหารไทยจะอยู่ในรูปแบบของ JSON Arrays ตามจำนวนป้ายที่พบในรูปภาพ ซึ่งแต่ละอาเรย์จะมีองค์ประกอบดังนี้
#
# OK : "True" หรือ "False"
# filename : ชื่อของไฟล์ภาพที่เซิร์ฟเวอร์รับมา ในกรณีที่ client ส่ง query มาหลายภาพ อาจใช้ชื่อไฟล์นี้ในการเทียบว่าเป็นคำตอบจากภาพใด
# objects : เป็นรายการของคำตอบที่น่าจะเป็น 10 อันดับแรก ในกรณีระบบพบว่าคำตอบในรายการนี้มีความน่าจะเป็นต่ำมาก (ต่ำกว่า 0.1) ระบบจะตัดรายการคำตอบให้สั้นลง โดยจำนวนคำตอบที่น้อยที่สุดคือ 1 คำตอบ (Array)
#  label: ชื่อของอาหาร เป็น utf-8 string ในกรณีที่คำตอบนี้มีความน่าจะเป็นต่ำกว่า 0.8 ระบบจะเพิ่มคำว่า "(น่าจะ)" ไว้หน้าชื่อ และหากความน่าจะเป็นต่ำกว่า 0.1 จะมีคำว่า "(เดาว่า)" นำหน้าชื่ออาหารนี้
#  rank: ลำดับของคำตอบมีค่าได้ 1-10 โดย 1 คือคำตอบที่เป็นไปได้มากที่สุด
# li> result: ชื่ออาหารไทยที่ได้
#  score: คะแนนของคำตอบนี้ มีค่าตั้งแต่ 0 -1
#  </pre>

# %% [markdown]
# **แสดงผลลัพธ์การรับรู้ว่ารูปภาพอาหารคืออาหารชนิดใด**

# %%
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw
from IPython.display import display

import sys
 
img = Image.open(image_thaifood)
draw = ImageDraw.Draw(img)
font = ImageFont.truetype('THSarabunNew Bold.ttf', 70)

json_data =response.json()

data = json_data['objects'][0]
msg = data['label'] +' score=' + data['score']

w, h = img.size  

color = (255,50,100)
draw.text((int(w*0.15), int(h*0.5)), msg, color, font=font)
#img.save(out_file)
display(img)

print()
print("ภาพอาหารคือ :", msg)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7FF80CE87FD0>
# ภาพอาหารคือ : (น่าจะ) ผัดหมี่ซั่วหมู score=0.11271966

# %% [markdown]
# # VISION : Object Character Recognition (T-OCR)
#
# ระบบแปลงภาพตัวอักษรภาษาไทยให้เป็นข้อความ

# %%
#@title กรอกข้อมูล เพื่อกำหนดค่าให้กับตัวแปร
Apikey = "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w" #@param {type:"string"}
url_ocr = "https://api.aiforthai.in.th/ocr" #@param {type:"string"}
image_ocr = "test_ocr.jpg" #@param {type:"string"}

# %% [markdown]
# **ดาวน์โหลดภาพตัวอย่าง**

# %%
# !wget https://raw.githubusercontent.com/adminho/machine-learning/master/Datasets/test_ocr.jpg -O /content/test_ocr.jpg
# Out:
# --2020-04-30 08:22:41--  https://raw.githubusercontent.com/adminho/machine-learning/master/Datasets/test_ocr.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 99505 (97K) [image/jpeg]
# Saving to: ‘/content/test_ocr.jpg’
#
# /content/test_ocr.j 100%[===================>]  97.17K  --.-KB/s    in 0.02s
#
# 2020-04-30 08:22:41 (4.51 MB/s) - ‘/content/test_ocr.jpg’ saved [99505/99505]

# %%
# หรือจะอัพโหลดไฟล์ขึ้นคลาวด์ด้วยโค้ดชุดนี้
'''
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
'''

# %% [markdown]
# **แสดงภาพตัวอย่าง**

# %%
display_image(image_ocr, scale=0.5)

# %% [markdown]
# **เรียกใช้ API**

# %%
import requests
 
# url = "https://api.aiforthai.in.th/ocr"
url = url_ocr

# files = {'uploadfile':open('test.jpg', 'rb')}
files = {'uploadfile':open(image_ocr, 'rb')}
 
headers = {
    #'Apikey': "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w",
    'Apikey': Apikey,
    }
 
response = requests.post(url, files=files, headers=headers)
 
print(response.json())
# Out:
# {'Original': " \n\n๐                  ๑\n\nค่าขอลากลับบาน\nดิฉันจะขอลา ถึงเวลาสมควรแล้ว\n| ด้วยกิจการมี กะระณีนั้นพึ่งกระทํา\nก อําลาทั้งพระพุทธและพระธรรม\n\n \n    \n   \n  \n  \n\nพระสงฆ์พร้อมด้วยจิตรอันนอบน้อม\n' พร้อมทังครู ผู้มีพระคุณๆ\n\n \n\nญที่ฉันทํา คงค้าชูและเกื้อหนุน\nสนับสนุน เป็นทุนไปในชาติหน้า '\nสําเภาทอง ล่องนที หนีสงสาร .\n| ข้ามโฮฆะและสงสาร ถึงวิมานทุกท่านเทอญ\nถึงนิพพานทุกท่านเทอญ\n\x0c", 'Spellcorrection': '\n\n\n\nค่าขอลากลับบาน \nดิฉันจะขอลาถึงเวลาสมควรแล้ว \n- ด้วยกิจการมีกะระชีนั้นพึ่งกระทำ \n- อำลาทั้งพระพุทธและพระธรรม \n\n\n\n\n\n\n\nพระสงฆ์พร้อมด้วยจิตรอนขอบน้อม \n- พร้อมทักครูผู้มีพระคุณๆ \n\n\n\n-ที่ฉันทำคงค้าชูและเกื้อหนุน \nสนับสนุนเป็นทุนไปในชาติหน้า - \n\n- ข้ามโทสะและสงสารถึงวิหารทุกท่านเทอก \nถึงนิพพานทุกท่านเทอก \n\n'}

# %% [markdown]
# <pre>
# OUTPUT
# ผลลัพธ์ที่ได้จากบริการแปลงภาพตัวอักษรภาษาไทยให้เป็นข้อความ จะอยู่ในรูปแบบของ JSON จะมีองค์ประกอบดังนี้
#
# Original :
# Spellcorrection :
# <pre/>

# %% [markdown]
# **แสดงผลลัพธ์การแปลงอักษรจากภาพเป็นตัวหนังสือ**

# %%
json_data = response.json()
print(json_data['Spellcorrection'])
# Out:
# ค่าขอลากลับบาน
# ดิฉันจะขอลาถึงเวลาสมควรแล้ว
# - ด้วยกิจการมีกะระชีนั้นพึ่งกระทำ
# - อำลาทั้งพระพุทธและพระธรรม
#
#
#
#
#
#
#
# พระสงฆ์พร้อมด้วยจิตรอนขอบน้อม
# - พร้อมทักครูผู้มีพระคุณๆ
#
#
#
# -ที่ฉันทำคงค้าชูและเกื้อหนุน
# สนับสนุนเป็นทุนไปในชาติหน้า -
#
# - ข้ามโทสะและสงสารถึงวิหารทุกท่านเทอก
# ถึงนิพพานทุกท่านเทอก

# %% [markdown]
# # VISION : Object Character Recognition (DeepOCR )
#
# OCR สำหรับอ่านตัวอักษรที่พบเจอได้ทั่วไป รวมถึงตัวอักษรที่มีลักษณะไม่สมบูรณ์ เช่น ตัวอักษรขาด ตัวอักษรติดกัน มีรอยแหว่ง ลอก เป็นต้น โดยลักษณะรูปจะต้องเป็นตัวอักษรภาษาอังกฤษ ตัวเลข หรืออักขระพิเศษที่เป็นแนวยาวมีขนาดพอดีกับตัวอักษร 1 บรรทัด และมีความยาว 6-18 ตัวอักษร

# %%
#@title กรอกข้อมูล เพื่อกำหนดค่าให้กับตัวแปร
Apikey = "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w" #@param {type:"string"}
url_deepocr = "https://api.aiforthai.in.th/panyapradit-ocr" #@param {type:"string"}
image_deepocr = "test_deepocr.jpg" #@param {type:"string"}

# %% [markdown]
# **ดาวน์โหลดภาพตัวอย่าง**

# %%
# !wget https://underthebridge.co.uk/wp-content/uploads/2014/03/Example-main-image1.jpg -O /content/test_deepocr.jpg
# Out:
# /bin/bash: -O: command not found
# --2020-05-21 09:33:45--  https://scontent.fnak3-1.fna.fbcdn.net/v/t1.0-9/p960x960/96376951_3115071648550909_7406599547796848640_o.png?_nc_cat=110
# Resolving scontent.fnak3-1.fna.fbcdn.net (scontent.fnak3-1.fna.fbcdn.net)... 110.164.32.146, 2403:6200:ffff:fb02:face:b00c:0:a7
# Connecting to scontent.fnak3-1.fna.fbcdn.net (scontent.fnak3-1.fna.fbcdn.net)|110.164.32.146|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2020-05-21 09:33:46 ERROR 403: Forbidden.

# %%
# หรือจะอัพโหลดไฟล์ขึ้นคลาวด์ด้วยโค้ดชุดนี้
'''
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
'''

# %% [markdown]
# **แสดงภาพตัวอย่าง**

# %%
display_image(image_deepocr, scale=0.5)

# %% [markdown]
# **เรียกใช้ API** (ยัง error รอทีมงานพัฒนา)

# %%
import requests
 
url = "https://api.aiforthai.in.th/panyapradit-ocr"
url = url_deepocr

files = {'uploadfile':open(image_deepocr, 'rb')}
 
headers = {
    #'Apikey': "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w",
    'Apikey': Apikey,
    }
 
response = requests.post(url, files=files, headers=headers)
 
#print(response.json())
print(response)
# Out:
# <Response [500]>

# %% [markdown]
# # VISION : Thai License Plate Recognition: T-LPR
#
# ระบบรู้จำป้ายทะเบียนรถยนต์สามารถตรวจหาอักษรภาษาไทยและตัวเลขอารบิกบนป้ายทะเบียนรถ
#
# * lpr: https://api.aiforthai.in.th/lpr
# * lpr v.2: https://api.aiforthai.in.th/lpr-v2

# %%
#@title กรอกข้อมูล เพื่อกำหนดค่าให้กับตัวแปร
Apikey = "BghsplRaCk6QRBZR5fX7krSjOdn1RS0w" #@param {type:"string"}
url_lpr = "https://api.aiforthai.in.th/lpr-v2" #@param {type:"string"}
image_lpr = "test_LPR_ocr.jpg" #@param {type:"string"}

# %% [markdown]
# **ดาวน์โหลดแผ่นป้ายทะเบียนรถจากอินเตอร์เนต**

# %%
# !wget http://a1.trd.cm/thaisecondhand/201106/173/9844128_0.jpg -O /content/test_LPR_ocr.jpg
# Out:
# --2020-04-30 07:40:27--  http://a1.trd.cm/thaisecondhand/201106/173/9844128_0.jpg
# Resolving a1.trd.cm (a1.trd.cm)... 52.77.75.17, 52.74.109.196, 18.136.223.48
# Connecting to a1.trd.cm (a1.trd.cm)|52.77.75.17|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16709 (16K) [image/jpeg]
# Saving to: ‘/content/test_LPR_ocr.jpg’
#
# /content/test_LPR_o 100%[===================>]  16.32K  94.5KB/s    in 0.2s
#
# 2020-04-30 07:40:27 (94.5 KB/s) - ‘/content/test_LPR_ocr.jpg’ saved [16709/16709]

# %%
# หรือจะอัพโหลดไฟล์ขึ้นคลาวด์ด้วยโค้ดชุดนี้
'''
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
'''

# %% [markdown]
# **แสดงภาพตัวอย่าง**

# %%
display_image(image_lpr, scale=1)

# %% [markdown]
# **เรียกใช้ API**

# %%
import requests
 
#url = "https://api.aiforthai.in.th/lpr-v2"
url = url_lpr
payload = {'crop': '1', 'rotate': '1'}
files = {'image':open(image_lpr, 'rb')}
 
headers = {
    'Apikey': Apikey,
    }

if url_lpr.endswith("v2") == False:
  data = None

response = requests.post( url, files=files, data = payload, headers=headers)

print(response.json())
# Out:
# [{'lpr': 'รข845', 'bbox': {'xLeftTop': '0', 'xRightBottom': '323', 'yRightBottom': '188', 'yLeftTop': '0'}}]

# %% [markdown]
# <pre>
# OUTPUT
# ผลลัพธ์ที่ได้จาก ระบบรู้จำป้ายทะเบียนรถยนต์ จะอยู่ในรูปแบบของ JSON Arrays ตามจำนวนป้ายที่พบในรูปภาพ ซึ่งแต่ละอาเรย์จะมีองค์ประกอบดังนี้
#
# lpr : ชุดตัวอักษรและตัวเลขของป้ายทะเบียน (String)
# bbox : ตำแหน่งบนรูปภาพที่พบป้ายทะเบียน (Array)
#  xLeftTop: ตำแหน่ง x ของป้ายทะเบียนมุมซ้ายบน
#  yLeftTop: ตำแหน่ง y ของป้ายทะเบียนมุมซ้ายบน
#  xRightBottom: ตำแหน่ง x ของป้ายทะเบียนมุมขวาล่าง
#  yRightBottom: ตำแหน่ง y ของป้ายทะเบียนมุมขวาล่าง
# </pre>

# %% [markdown]
# **วาดรูปแสดงผล (Visualization)**

# %%
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw
from IPython.display import display

import sys
 
img = Image.open(image_lpr)
draw = ImageDraw.Draw(img)
font = ImageFont.truetype('THSarabunNew Bold.ttf', 70)

json_data =response.json()

data = json_data[0]
msg = data['lpr']
bbox = data['bbox']
w, h = img.size  

color = (255,50,100)
draw.text((int(w*0.15), int(h*0.5)), msg, color, font=font)

x0, y0 = int(bbox['xLeftTop']), int(bbox['yLeftTop'])
x1, y1 = int(bbox['xRightBottom']), int(bbox['yRightBottom'])

draw.rectangle([x0, y0, x1, y1], outline ="red")
#img.save(out_file)
display(img)

print()
print("ป้ายทะเบียนคือ :", msg)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=405x188 at 0x7FF80C6293C8>
# ป้ายทะเบียนคือ : รข845

# %% [markdown]
# # ฝากติดตาม
#
# <img height="20px" src="https://www.patanasongsivilai.com/blog/wp-content/uploads/2017/06/logo_facebook2.png" align="left" hspace="10px" vspace="0px">  https://www.facebook.com/programmerthai/
#
# <img height="14px" src="https://www.patanasongsivilai.com/blog/wp-content/uploads/2019/03/youtube.png" align="left" hspace="10px" vspace="3px">  https://www.youtube.com/channel/UCvhCKtG5cRE6K5--RJPql_w
#
# <img height="14px" src="https://www.patanasongsivilai.com/blog/wp-content/uploads/2019/09/github-2.jpg" align="left" hspace="10px" vspace="3px">https://github.com/adminho/machine-learning

# %% [markdown]
# # ฝากประชาสัมพันธ์

# %%
#@title หนังสือ AI (ปัญญาประดิษฐ์) ไม่ยาก เรียนรู้ได้ด้วยเลขม. ปลาย ราคา 295 บาท
# %%HTML
<iframe src="https://www.facebook.com/plugins/post.php?href=https%3A%2F%2Fwww.facebook.com%2Fprogrammerthai%2Fphotos%2Fa.2410667485889755%2F2555677101388792%2F%3Ftype%3D3&width=500" width="500" height="588" style="border:none;overflow:hidden" scrolling="no" frameborder="0" allowTransparency="true" allow="encrypted-media"></iframe>
# Out:
# <iframe src="https://www.facebook.com/plugins/post.php?href=https%3A%2F%2Fwww.facebook.com%2Fprogrammerthai%2Fphotos%2Fa.2410667485889755%2F2555677101388792%2F%3Ftype%3D3&width=500" width="500" height="588" style="border:none;overflow:hidden" scrolling="no" frameborder="0" allowTransparency="true" allow="encrypted-media"></iframe>
